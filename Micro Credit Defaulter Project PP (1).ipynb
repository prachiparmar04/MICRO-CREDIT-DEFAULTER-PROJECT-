# %% [markdown]
# # MICRO CREDIT DEFAULTER PROJECT
#
#         @Prachi Parmar
#
#
#    ### Problem Statement
#
#      A Microfinance Institution (MFI) is an organization that offers financial services to low income populations. MFS becomes very useful when targeting especially the unbanked poor families living in remote areas with not much sources of income. The Microfinance services (MFS) provided by MFI are Group Loans, Agricultural Loans, Individual Business Loans and so on.
#     Many microfinance institutions (MFI), experts and donors are supporting the idea of using mobile financial services (MFS) which they feel are more convenient and efficient, and cost saving, than the traditional high-touch model used since long for the purpose of delivering microfinance services. Though, the MFI industry is primarily focusing on low income families and are very useful in such areas, the implementation of MFS has been uneven with both significant challenges and successes.
#
#     We are working with one such client that is in Telecom Industry. They are a fixed wireless telecommunications network provider. They have launched various products and have developed its business and organization based on the budget operator model, offering better products at Lower Prices to all value conscious customers through a strategy of disruptive innovation that focuses on the subscriber.
#     They understand the importance of communication and how it affects a person’s life, thus, focusing on providing their services and products to low income families and poor customers that can help them in the need of hour.
#     They are collaborating with an MFI to provide micro-credit on mobile balances to be paid back in 5 days. The Consumer is believed to be defaulter if he deviates from the path of paying back the loaned amount within the time duration of 5 days. For the loan amount of 5 (in Indonesian Rupiah), payback amount should be 6 (in Indonesian Rupiah), while, for the loan amount of 10 (in Indonesian Rupiah), the payback amount should be 12 (in Indonesian Rupiah).
#
#
#     The sample data is provided to us from our client database. It is hereby given to you for this exercise. In order to improve the selection of customers for the credit, the client wants some predictions that could help them in further investment and improvement in selection of customers.
#
#
#
# ### Attributes/ Features:
#
#       -  35 Features, 1 Target Variable (Success ( Repayed Loan) -1, Fail ( Did Not Repay ) -0)
#
#        - Target Class:
#
#             1. label - TARGET CLASS
#
#        - Features:
#
#             2. msisdn
#             3. aon
#             4. daily_decr30
#             5. daily_decr90
#             6. rental30
#             7. rental90
#             8. last_rech_date_ma
#             9. last_rech_date_da
#             10. last_rech_amt_ma
#             11. cnt_ma_rech30
#             12. fr_ma_rech30
#             13. sumamnt_ma_rech30
#             14. medianamnt_ma_rech30
#             15. medianmarechprebal30
#             16. cnt_ma_rech90
#             17. fr_ma_rech90
#             18. sumamnt_ma_rech90
#             19. medianamnt_ma_rech90
#             20. medianmarechprebal90
#             21. cnt_da_rech30
#             22. fr_da_rech30
#             23. cnt_da_rech90
#             24. fr_da_rech90
#             25. cnt_loans30
#             26. amnt_loans30
#             27. maxamnt_loans30
#             28. medianamnt_loans30
#             29. cnt_loans90
#             30. amnt_loans90
#             31. maxamnt_loans90
#             32. medianamnt_loans90
#             33. payback30
#             34. payback90
#             35. pcircle
#             36. pdate3
#
#
# #### Conclusion:
#
#     Build a model which can be used to predict in terms of a probability for each loan transaction, whether the customer will be paying back the loaned amount within 5 days of insurance of loan. In this case, Label ‘1’ indicates that the loan has been payed i.e. Non- defaulter, while, Label ‘0’ indicates that the loan has not been payed i.e. defaulter.

# %% [markdown]
# #### STEP 1: DATA PREPARATION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv('Downloads/Micro-Credit-Project/Micro Credit Project/Data file.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
data.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
for i in data.columns:
    print(i)
    print(data[i].value_counts())
# Out:
# label
# 1    183431
# 0     26162
# Name: label, dtype: int64
# msisdn
# 04581I85330    7
# 47819I90840    7
# 43096I88688    6
# 87592I84456    6
# 22038I88658    6
#               ..
# 67128I70371    1
# 06934I85340    1
# 35359I70786    1
# 02856I70782    1
# 85854I90581    1
# Name: msisdn, Length: 186243, dtype: int64
# aon
# 95.000000        392
# 92.000000        362
# 96.000000        357
# 99.000000        356
# 157.000000       349
#                 ...
# 752400.263562      1
# 565434.285440      1
# 931525.183027      1
# 929670.835962      1
# 972326.532821      1
# Name: aon, Length: 4507, dtype: int64
# daily_decr30
# 0.000000       4144
# 500.000000      829
# 1000.000000     569
# 700.000000      381
# 600.000000      354
#                ...
# 3565.333333       1
# 596.172000        1
# 700.126667        1
# 7604.514667       1
# 4108.476000       1
# Name: daily_decr30, Length: 147026, dtype: int64
# daily_decr90
# 0.000        4063
# 500.000       781
# ...

# %% [markdown]
#  ##### OBSERVATIONS:
#     - Target Classs is imbalanced containing 87.5% of Class 1 (Repayed Customers)
#     -  For, msisdn, there are some repeated phnoe number data, also it should be Integer type , we replace a Seperator | with '' (None ) to convert it into a Number Format.
#     - aon, Age of Network in Days cannot be a Float TYype, we convert it into Integer type.
#     - last_rech_date_ma, last_rech_date_da should in Int as it is no of Days and cannot be negative
#     - fr_ma_rech30/ cnt_da_rech30 / fr_da_rech30 should be in Int as it no of time (frequency)
#     - amt_loans30/90 sohuld always be in mulitpe or 6,12 as loan amount to be repayed is either6,12 or in thier multiples.
#     - max_amount has some values which are nto multiple or 6/12 , they must be outliers.
#     - cnt_loans should be in integer format.
#     - payback 30/90 has a wide range, but optimal no of days  for repayment of loan is 5 days.
#     - pcircle has onyl 1 type, all loan transaction data is of UPW , we can omit this column.
#     - pdate : loan Transcation Date

# %% [markdown]
# **FIXINIG Column MSISDN and changing dtypes of other columns**

# %%
data['msisdn'] = data['msisdn'].apply(lambda x : x.replace('I',''))

# %%
data['aon'] = data['aon'].astype('int')
data['last_rech_date_da'] = data['last_rech_date_da'].astype('int')
data['last_rech_date_ma'] = data['last_rech_date_ma'].astype('int')
data['fr_da_rech30'] = data['fr_da_rech30'].astype('int')
data['fr_ma_rech30']  = data['fr_ma_rech30'].astype('int')
data['cnt_da_rech30'] = data['cnt_da_rech30'].astype('int')
data['cnt_loans90'] = data['cnt_loans90'].astype('int')
data['last_rech_amt_ma'] = data['last_rech_amt_ma'].astype('float')
data['sumamnt_ma_rech90'] = data['sumamnt_ma_rech90'].astype('float')
data['amnt_loans30'] = data['amnt_loans30'].astype('float')
data['amnt_loans90'] = data['amnt_loans90'].astype('float')
data['maxamnt_loans90'] = data['maxamnt_loans90'].astype('float')
data.drop('pcircle',axis=1,inplace=True)

# %%
data.dtypes
# Out:
# label                     int64
# msisdn                   object
# aon                       int32
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma         int32
# last_rech_date_da         int32
# last_rech_amt_ma        float64
# cnt_ma_rech30             int64
# fr_ma_rech30              int32
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90       float64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30             int32
# fr_da_rech30              int32
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30            float64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90               int32
# ...

# %%
data['msisdn'].value_counts()
# Out:
# 4781990840    7
# 0458185330    7
# 6074491197    6
# 8759284456    6
# 7174290843    6
#              ..
# 8083289239    1
# 2400170785    1
# 2463082730    1
# 4728884455    1
# 9940599976    1
# Name: msisdn, Length: 186243, dtype: int64

# %% [markdown]
# ##### Checking DIstribution of all columns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(6,4 ))
sb.countplot(data['label'],palette='Set1')
plt.title('Loan Repayment Fail Vs Success')
plt.xticks([0,1],['Defaulter','Non Defaulter'])
plt.xlabel('Target Class')
# Out:
# Text(0.5, 0, 'Target Class')

# %% [markdown]
# **Observations**
# - Imbalanced Classes

# %%
data.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.338432    5381.402289    6082.515068
# std         0.330519   75696.033577    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.000000  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.845343        3712.200350
# std      4308.586781    5770.461279       53905.858216       53374.797848
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
data['aon'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### OBservation:
#
#     AS AON has some extreme values, we replace the extreme vlaues with Nan as the extreme values are unrealistic and causing issues in visulaization of true nature fo the Feature
#
#     AS you can see below, age of network with Value around 929670 is realistic so we replace it with Nan as most of the Aon vlaues are under 2500
#     - Assumption : that Aon cannot be greater than 2500 as most  99% vlaues are below that level

# %%
data['aon'] = data['aon'].apply(lambda x: x if x<2500 else np.NaN)

# %%
plt.figure(figsize=(6,4 ))
sb.boxplot(data['aon'])
plt.title('Age of Network')
plt.xlabel('Age of Network')
# Out:
# Text(0.5, 0, 'Age of Network')

# %%
plt.figure(figsize=(6,4 ))
sb.displot(data['aon'])
plt.title('Age of Network')
plt.xlabel('Age of Network')
# Out:
# Text(0.5, 6.79999999999999, 'Age of Network')

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['aon'],data['label'])
plt.title('Age of Network in Vs DEfualter/NonDefaulter')
plt.xlabel('Age of Network')
plt.ylabel('Defaulter - 0/ Non Defaulter - 1')
# Out:
# Text(0, 0.5, 'Defaulter - 0/ Non Defaulter - 1')

# %%
plt.figure(figsize=(6,4 ))
sb.barplot(data['label'],data['aon'])
plt.xticks([0,1],['Defaulter','Non Defaulter'])
plt.title('Age of Network')
plt.xlabel('Age of Network')
# Out:
# Text(0.5, 0, 'Age of Network')

# %% [markdown]
# #### **Observations**
#     - WE replace the Non reliastic values of AOn for better visualization and visualize the data,
#     - we also see, by the scatter plot with Target Varialbe, Aon have same range of Values lieing in both TArget Category, telling us very less about the feature distinction.
#
#
#   #### Visualizing Daily Spent Amount Details: daily_decr30/90: Removing Unrealistic Extreme Values

# %%
data['daily_decr30'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data['daily_decr90'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data[data['daily_decr30'] > 100000]
# Out:
#         label      msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 6162        1  5320988658   980.0    167089.000     194024.49  25600.25
# 7960        1  0283290844   875.0    112822.530     114089.95  16720.06
# 12680       1  2816770372   212.0    139127.000     193414.33  18120.34
# 16393       1  6217089233  1343.0    108803.552     109840.48   3748.99
# 16701       1  0281589237  1251.0    161598.000     192796.54  13662.34
# ...       ...         ...     ...           ...           ...       ...
# 189257      1  1228782735   137.0    123502.000     175609.69   9482.91
# 190885      1  6292989232   742.0    122880.944     123501.86  12075.13
# 193084      1  4618070375   689.0    212202.000     254657.13  22563.55
# 206710      1  8028284454   223.0    106577.000     170863.60   9261.34
# 207567      1  6669990583   781.0    102406.000     153727.18  15684.28
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
plt.figure(figsize=(6,4 ))
sb.barplot(data['label'],data['daily_decr30'])
plt.title('30 days Average daily Spend Amount for Each Target Class')
plt.ylabel('30 days Average daily Spend Amount')
plt.xlabel('Target Class')
plt.xticks([0,1],['Defaulter','NonDefaulter'])
# Out:
# ([<matplotlib.axis.XTick at 0x1fa094fd850>,
# ...
#  [Text(0, 0, 'Defaulter'), Text(1, 0, 'NonDefaulter')])

# %%
plt.figure(figsize=(6,4 ))
sb.barplot(data['label'],data['daily_decr90'])
plt.title('90 days Average daily Spend Amount')
plt.ylabel('90 days Average daily Spend Amount')
plt.xlabel('Target Class')
plt.xticks([0,1],['Defaulter','NonDefaulter'])
# Out:
# ([<matplotlib.axis.XTick at 0x1fa096c6ee0>,
# ...
#  [Text(0, 0, 'Defaulter'), Text(1, 0, 'NonDefaulter')])

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['label'],data['daily_decr30'])
plt.title('30 days Average daily Spend Amount')
plt.ylabel('30 days Average daily Spend Amount')
plt.xlabel('Defaulter Class - 0 , Non Defaulter Class - 1')
# Out:
# Text(0.5, 0, 'Defaulter Class - 0 , Non Defaulter Class - 1')

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['label'],data['daily_decr90'])
plt.title('90 days Average daily Spend Amount')
plt.ylabel('90 days Average daily Spend Amount')
plt.xlabel('Defaulter Class - 0 , Non Defaulter Class - 1')
# Out:
# Text(0.5, 0, 'Defaulter Class - 0 , Non Defaulter Class - 1')

# %%
plt.figure(figsize=(14,4 ))
sb.kdeplot(data['daily_decr30'],hue= data['label'])
plt.title('30 days Average daily Spend Amount')
plt.xlabel('30 days Average Daily Spent Amount')
plt.legend(['Defaulter','NonDefaulter'])

# %%
plt.figure(figsize=(14,4 ))
sb.kdeplot(data['daily_decr90'],hue= data['label'])
plt.title('90 days Average daily Spend Amount')
plt.xlabel('90 days Average Daily Spent Amount')
plt.legend(['Defaulter','NonDefaulter'])

# %% [markdown]
# ##### Observation ,
#     - We cannot Remove the outliers in this columns as it is Necessery Information
#     - Daily Spend amount 30/90 days average having large high spent amount are not Defaulters, THese high Values may seem like OUtliers as they but these outliers gives information about the a trasaction bieng not a deafualter.
#     - AS we can see Daily Spend amount for Defaulter ranges from 0 to 2.5lac , Range Of Daily Spend for Non Defualters are from concentrated in 0,75000
#     - Daily Spend Tells us about the Target Class
#
#   #### Visualizing Retal30 /90 : average Main accuont balance

# %%
plt.figure(figsize=(6,4 ))
sb.boxplot(data['rental30'])
plt.title('Average Main Account balance')
plt.xlabel('Average Main Account balance')
# Out:
# Text(0.5, 0, 'Average Main Account balance')

# %%
data[(data['rental30']<0) &(data['label'] ==0) ]
# Out:
#         label      msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 24          0  5964582735   966.0    291.563333    291.563333  -2020.09
# 246         0  5103595202   379.0    131.490000    131.490000   -229.77
# 1469        0  6555984458   247.0    114.957333    114.957333   -163.90
# 1777        0  0559988650   183.0     19.266667     19.266667   -121.21
# 2681        0  8239870780   321.0    159.293333    159.293333   -443.04
# ...       ...         ...     ...           ...           ...       ...
# 207113      0  4883788648   427.0     45.645333     45.645333   -278.64
# 207949      0  0283985348   809.0    495.987000    495.987000  -3719.25
# 208543      0  6773388648   897.0     70.649333     70.649333   -187.00
# 209175      0  2155670374   132.0    125.890667    125.890667  -1126.16
# 209231      0  2024782735  1140.0    733.433333    759.000000    -89.93
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
# After Continionally checking for relations, we have equal distribution of rentals beteeen both classes

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['label'],data['rental30'])
plt.title('30 days Average Main Account Balance')
plt.ylabel('30 days Average  Main Account Balance')
plt.xlabel('Defaulter Target Class- 0 /Non Defaulter Class -1')
# Out:
# Text(0.5, 0, 'Defaulter Target Class- 0 /Non Defaulter Class -1')

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['label'],data['rental90'])
plt.title('90 days Average Main Account Balance')
plt.ylabel('90 days Average  Main Account Balance')
plt.xlabel('Defaulter Target Class- 0 /Non Defaulter Class -1')
# Out:
# Text(0.5, 0, 'Defaulter Target Class- 0 /Non Defaulter Class -1')

# %%
plt.figure(figsize=(6,4 ))
sb.barplot(data['label'],data['rental90'])
plt.title('90 days Average  Main Account Balance')
plt.ylabel('90 days Average  Main Account Balance')
plt.xlabel('Target Class')
plt.xticks([0,1],['Defaulter','Non Defaulter'])
# Out:
# ([<matplotlib.axis.XTick at 0x1fa09811310>,
# ...
#  [Text(0, 0, 'Defaulter'), Text(1, 0, 'Non Defaulter')])

# %%
plt.figure(figsize=(6,4 ))
sb.barplot(data['label'],data['rental30'])
plt.title('30 days Average  Main Account Balance')
plt.ylabel('30 days Average  Main Account Balance')
plt.xlabel('Target Class')
plt.xticks([0,1],['Defaulter','Non Defaulter'])
# Out:
# ([<matplotlib.axis.XTick at 0x1fa09a3f790>,
# ...
#  [Text(0, 0, 'Defaulter'), Text(1, 0, 'Non Defaulter')])

# %% [markdown]
# **Observations**
#     - Rental30/90 show some significance with the target Class having Non defualters Average main account Balance  Higher than Non defaulter,
#
#
#
# ##### Last Recharge Date MA,DA have some non realistic Values and also as we checknig the dataset for past 90 days history the Last rechrage days sohuld not be greater than 90 and cannot be negative

# %%
data[(data['last_rech_date_ma']>90) | (data['last_rech_date_da']>90)| (data['last_rech_date_ma']<0)
     | (data['last_rech_date_da']<0)  ]
#these values are Unrealistic we replace the values with Nan
# Out:
#         label      msisdn    aon  daily_decr30  daily_decr90  rental30  \
# 30          1  7013090843  -42.0      8.864333      8.864333    780.71
# 53          1  0956170374  635.0      5.500000      5.500000     75.90
# 129         1  4343190847  347.0     47.466667     47.466667    186.80
# 159         1  8466785348  415.0   9507.542667   9622.480000    418.58
# 195         1  5645485340  560.0     13.572000     13.572000    365.30
# ...       ...         ...    ...           ...           ...       ...
# 209442      1  1836885338  176.0   7934.220000   8010.320000   3188.33
# 209466      1  5952588698  190.0   2601.750000   2622.100000   -334.62
# 209501      1  5464270787  460.0     55.520000     55.520000    877.40
# 209531      1  6829670378  238.0  13619.964000  13699.820000   1588.43
# 209533      0  4167295204  168.0     15.400000     15.400000    922.20
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
data['last_rech_date_ma'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data['last_rech_date_da'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data['last_rech_date_ma'] = data['last_rech_date_ma'].apply(lambda x: x if (x<90) else np.NaN)
data['last_rech_date_ma'] = data['last_rech_date_ma'].apply(lambda x: np.NaN if x < 0 else x )

# %%
data['last_rech_date_da'] = data['last_rech_date_da'].apply(lambda x: x if (x<90) else np.NaN)
data['last_rech_date_da'] = data['last_rech_date_da'].apply(lambda x: np.NaN if x < 0 else x )

# %%
data['last_rech_date_da'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data['last_rech_date_ma'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['label'],data['last_rech_date_da'])
plt.title('No of Days Since LAst Recharge(in Days) in Data Account')
plt.ylabel('No of Days Since LAst Recharge(in Days) ')
plt.xlabel('Defaulter Target Class- 0 /Non Defaulter Class -1')
# Out:
# Text(0.5, 0, 'Defaulter Target Class- 0 /Non Defaulter Class -1')

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['label'],data['last_rech_date_ma'])
plt.title('No of Days Since LAst Recharge(in Days) in Main Account')
plt.ylabel('No of Days Since LAst Recharge(in Days) ')
plt.xlabel('Defaulter Target Class- 0 /Non Defaulter Class -1')
# Out:
# Text(0.5, 0, 'Defaulter Target Class- 0 /Non Defaulter Class -1')

# %%
plt.figure(figsize=(6,4 ))
sb.barplot(data['label'],data['last_rech_date_ma'])
plt.xticks([0,1],['Defaulter','Non Defaulter'])
plt.title('Last Recharge in No of Days')
plt.ylabel('Last Recharge in No of Days')
# Out:
# Text(0, 0.5, 'Last Recharge in No of Days')

# %% [markdown]
# ##### **Observations**
#     - Both Target Classes have Same Ranges of No last_rech_days

# %%
data[(data['fr_ma_rech30']>200)][['cnt_ma_rech30','fr_ma_rech30']]
   #  | (data['last_rech_date_ma']<0) | (data['last_rech_date_da']<0)  ]
#these values are Unrealistic we replace the values with Nan
# Out:
#         cnt_ma_rech30  fr_ma_rech30
# 248                 2        666606
# 501                 1        515400
# 896                 2        748610
# 1020                1        761778
# 1433                5        969456
# ...               ...           ...
# 208420              3        929808
# 208429              1        827661
# 208847              2        905481
# 208857              2        620381
# 209291              9        747564
#
# [1047 rows x 2 columns]

# %%
data['fr_ma_rech30'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data[['cnt_ma_rech30','fr_ma_rech30','cnt_ma_rech90','fr_ma_rech90']].describe()
# Out:
#        cnt_ma_rech30   fr_ma_rech30  cnt_ma_rech90   fr_ma_rech90
# count  209593.000000  209593.000000   209593.00000  209593.000000
# mean        3.978057    3737.352626        6.31543       7.716780
# std         4.256090   53643.590642        7.19347      12.590251
# min         0.000000       0.000000        0.00000       0.000000
# 25%         1.000000       0.000000        2.00000       0.000000
# 50%         3.000000       2.000000        4.00000       2.000000
# 75%         5.000000       6.000000        8.00000       8.000000
# max       203.000000  999606.000000      336.00000      88.000000

# %% [markdown]
# #### From Above Table, Only Fr_ma_rech has1047  extreme UnRealistic Values

# %%
data['fr_ma_rech30'] =data['fr_ma_rech30'].apply(lambda x: x if x<250 else np.NaN)

# %%
data[['cnt_da_rech30','fr_da_rech30','cnt_da_rech90','fr_da_rech90']].describe()
# Out:
#        cnt_da_rech30   fr_da_rech30  cnt_da_rech90   fr_da_rech90
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean      262.575597    3749.491953       0.041495       0.045712
# std      4183.866730   53885.380285       0.397556       0.951386
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max     99914.000000  999809.000000      38.000000      64.000000

# %%
data[(data['cnt_da_rech30']>500) | (data['fr_da_rech30']>500)][['cnt_da_rech30','fr_da_rech30']]
# Out:
#         cnt_da_rech30  fr_da_rech30
# 112             30721             0
# 114                 0        723845
# 121             91764             0
# 594                 0        770942
# 1490            11039             0
# ...               ...           ...
# 208695          35132             0
# 208696          61002             0
# 208915              0        744924
# 209412              0        704094
# 209451              0        509386
#
# [2086 rows x 2 columns]

# %%
data['cnt_da_rech30'] =data['cnt_da_rech30'].apply(lambda x: x if x<250 else np.NaN)
data['fr_da_rech30'] =data['fr_da_rech30'].apply(lambda x: x if x<250 else np.NaN)

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['label'],data['last_rech_date_ma'])
plt.title('No of Days Since LAst Recharge(in Days) in Main Account')
plt.ylabel('No of Days Since LAst Recharge(in Days) ')
plt.xlabel('Target Class')
# Out:
# Text(0.5, 0, 'Target Class')

# %%
cols = ['cnt_da_rech30','fr_da_rech30','cnt_da_rech90','fr_da_rech90',
        'cnt_ma_rech30','fr_ma_rech30','cnt_ma_rech90','fr_ma_rech90'
 ]

# %%
for i in cols:
    plt.figure(figsize=(6,6))
    sb.scatterplot(data['label'],data[i])
    plt.title(i)

# %% [markdown]
# ###### Observations
#     -Some features show distincts value ranges for targets.
#
#
# ##### Note:
#     - Last Recharge Amount has not Extreme unrealistic vlaues

# %%
data['last_rech_amt_ma'].describe()
#No Extreme Values
# Out:
# count    209593.000000
# mean       2064.452797
# std        2370.786034
# min           0.000000
# 25%         770.000000
# 50%        1539.000000
# 75%        2309.000000
# max       55000.000000
# Name: last_rech_amt_ma, dtype: float64

# %%
plt.figure(figsize=(6,4 ))
sb.barplot(data['label'],data['last_rech_amt_ma'])
plt.title('Last Recharge Amount in Main Account')
plt.ylabel('Last Recharge Amount in Main Account')
plt.xticks([0,1],['Defaulter','Non Defaulter'])
# Out:
# ([<matplotlib.axis.XTick at 0x1fa0eaf3ac0>,
# ...
#  [Text(0, 0, 'Defaulter'), Text(1, 0, 'Non Defaulter')])

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['label'],data['last_rech_amt_ma'])
plt.title('Last Recharge Amount in Main Account')
plt.ylabel('Last Recharge Amount in Main Account')
plt.xlabel('Target Class')
# Out:
# Text(0.5, 0, 'Target Class')

# %% [markdown]
# ###### Observation
#     - Uniform Distribution of last recharge around Targets ,

# %%
data[['medianamnt_loans30','medianamnt_loans90']].describe()
#No Extreme Values
# Out:
#        medianamnt_loans30  medianamnt_loans90
# count       209593.000000       209593.000000
# mean             0.054029            0.046077
# std              0.218039            0.200692
# min              0.000000            0.000000
# 25%              0.000000            0.000000
# 50%              0.000000            0.000000
# 75%              0.000000            0.000000
# max              3.000000            3.000000

# %%
data[['sumamnt_ma_rech90','sumamnt_ma_rech30']].describe()
# Out:
#        sumamnt_ma_rech90  sumamnt_ma_rech30
# count      209593.000000      209593.000000
# mean        12396.218352        7704.501157
# std         16857.793882       10139.621714
# min             0.000000           0.000000
# 25%          2317.000000        1540.000000
# 50%          7226.000000        4628.000000
# 75%         16000.000000       10010.000000
# max        953036.000000      810096.000000

# %%
sb.boxplot(data['sumamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech30'>

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['sumamnt_ma_rech30'],data['label'])
plt.title('30 Days Avg of Total Amount of Recharge Done for Main Account.')
plt.xlabel(' 30 Days Avg of Total Amount of Recharge Done for Main Account.')
plt.ylabel('Defaulter Target Class- 0 /Non Defaulter Class -1')
# Out:
# Text(0, 0.5, 'Defaulter Target Class- 0 /Non Defaulter Class -1')

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['sumamnt_ma_rech90'],data['label'])
plt.title('90 Days Avg of Total Amount of Recharge done for Main Account.')
plt.xlabel('90 Days Avg of Total Amount of Recharge done for Main Account.')
plt.ylabel('Defaulter Target Class- 0 /Non Defaulter Class -1')
# Out:
# Text(0, 0.5, 'Defaulter Target Class- 0 /Non Defaulter Class -1')

# %%
sb.scatterplot(data['medianamnt_ma_rech30'],data['label'])
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech30', ylabel='label'>

# %%
sb.scatterplot(data['medianamnt_ma_rech90'],data['label'])
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech90', ylabel='label'>

# %%
sb.scatterplot(data['medianmarechprebal30'],data['label'])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal30', ylabel='label'>

# %%
sb.scatterplot(data['medianmarechprebal90'],data['label'])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal90', ylabel='label'>

# %% [markdown]
# ##### **Observations**
#     - no relations found with target in medianprebal , medianamount
#     - SumAomunt 30/90 avg has a a Range Defined with Targets
#
#
# #### NOTE:
#     No Extreme values for 'cnt_loans30','amnt_loans30','amnt_loans90'
#     -  Cnt_laons90 has some extreme values as count cannot be in float

# %%
data[['cnt_loans30','cnt_loans90','amnt_loans30','amnt_loans90']].describe()
#No Extreme Values
# Out:
#          cnt_loans30    cnt_loans90   amnt_loans30   amnt_loans90
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        2.758981      18.518452      17.952021      23.645398
# std         2.554502     224.764898      17.379741      26.469861
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       1.000000       6.000000       6.000000
# 50%         2.000000       2.000000      12.000000      12.000000
# 75%         4.000000       5.000000      24.000000      30.000000
# max        50.000000    4997.000000     306.000000     438.000000

# %%
data[data['cnt_loans90']>88][['cnt_loans30','cnt_loans90','amnt_loans30','amnt_loans90']]
# Out:
#         cnt_loans30  cnt_loans90  amnt_loans30  amnt_loans90
# 121               6         2340          36.0          36.0
# 504               1         3565           6.0           6.0
# 690               2         2687          12.0          12.0
# 840               2         2277          12.0          12.0
# 841               1         1962           6.0           6.0
# ...             ...          ...           ...           ...
# 208684            4         4801          24.0          24.0
# 208894            3         1564          18.0          18.0
# 208943            3         3027          18.0          18.0
# 209315            1         4479           6.0           6.0
# 209435            4         2047          24.0          36.0
#
# [1047 rows x 4 columns]

# %%
data['cnt_loans90'] = data['cnt_loans90'].apply(lambda x: x if x<88 else np.NaN)

# %%
plt.figure(figsize=(6,5))
sb.barplot(data['label'],data['amnt_loans90'])
plt.xticks([0,1],['Defaulter','Non Defaulter'])
plt.title('amount of loans taken in 90 Days Average')
# Out:
# Text(0.5, 1.0, 'amount of loans taken in 90 Days Average')

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['cnt_loans30'],data['label'])
plt.title('30 Days Avg of count of loans taken.')
plt.xlabel('30 Days Avg of count of loans taken.')
plt.ylabel('Defaulter Target Class- 0 /Non Defaulter Class -1')
# Out:
# Text(0, 0.5, 'Defaulter Target Class- 0 /Non Defaulter Class -1')

# %%
plt.figure(figsize=(6,4 ))
sb.scatterplot(data['cnt_loans90'],data['label'])
plt.title('90 Days Avg of count of loans taken.')
plt.xlabel('90 Days Avg of count of loans taken.')
plt.ylabel('Defaulter Target Class- 0 /Non Defaulter Class -1')
# Out:
# Text(0, 0.5, 'Defaulter Target Class- 0 /Non Defaulter Class -1')

# %%
sb.scatterplot(data['amnt_loans30'],data['label'])

plt.figure(figsize=(6,4 ))
sb.scatterplot(data['amnt_loans30'],data['label'])
plt.title('Total Amount of loans taken in 30 Days.')
plt.xlabel('Total Amount of loans taken in 30 Days.')
plt.ylabel('Defaulter Target Class- 0 /Non Defaulter Class -1')
# Out:
# Text(0, 0.5, 'Defaulter Target Class- 0 /Non Defaulter Class -1')

# %%
sb.scatterplot(data['amnt_loans90'],data['label'])
# Out:
# <AxesSubplot:xlabel='amnt_loans90', ylabel='label'>

# %% [markdown]
# ##### Observations
#
#     - amt_loans30/90 , cnt_loans30 have defined ranges for targets, cnt_laons90 do not have defined boundaries for targets.
#
#     -  No extreme values for 'maxamnt_loans90','medianamnt_loans30','medianamnt_loans90'
#     - extreme Values for maxAmount_laons_30 it can only be in multiple of 6/12

# %%
data[['maxamnt_loans30','maxamnt_loans90','medianamnt_loans30','medianamnt_loans90']].describe()
# Out:
#        maxamnt_loans30  maxamnt_loans90  medianamnt_loans30  \
# count    209593.000000    209593.000000       209593.000000
# mean        274.658747         6.703134            0.054029
# std        4245.264648         2.103864            0.218039
# min           0.000000         0.000000            0.000000
# 25%           6.000000         6.000000            0.000000
# 50%           6.000000         6.000000            0.000000
# 75%           6.000000         6.000000            0.000000
# max       99864.560864        12.000000            3.000000
#
#        medianamnt_loans90
# count       209593.000000
# mean             0.046077
# std              0.200692
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max              3.000000

# %%
data[data['maxamnt_loans30']>13][['maxamnt_loans30','maxamnt_loans90','medianamnt_loans30','medianamnt_loans90']]
# Out:
#         maxamnt_loans30  maxamnt_loans90  medianamnt_loans30  \
# 118        61907.697372              6.0                 0.0
# 125        22099.413732              6.0                 0.5
# 146        98745.934048              6.0                 0.5
# 369        58925.364061              6.0                 0.0
# 374        78232.464324             12.0                 0.0
# ...                 ...              ...                 ...
# 209189     50824.996349             12.0                 1.0
# 209262     17324.994582              6.0                 0.0
# 209331     92864.501728              6.0                 0.0
# 209392     54259.265687              6.0                 0.0
# 209424     96927.243252              6.0                 0.0
#
#         medianamnt_loans90
# 118                    0.0
# 125                    0.5
# 146                    0.0
# 369                    0.0
# 374                    0.0
# ...                    ...
# 209189                 1.0
# ...

# %%
data['maxamnt_loans30'] = data['maxamnt_loans30'].apply(lambda x: x if x<13 else np.NaN)

# %%
sb.scatterplot(data['maxamnt_loans30'],data['label'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans30', ylabel='label'>

# %%
sb.scatterplot(data['maxamnt_loans90'],data['label'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans90', ylabel='label'>

# %% [markdown]
# ##### Observations:  max_amount30/90 with 0 is always Non DEfaulter as to be a Defaulter , a amount will always be taken to not repay it.

# %%
data[data['maxamnt_loans90']==0]
# Out:
#         label      msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 127         1  5658970788   111.0        1820.0       2221.40   1068.68
# 149         1  2436070784   634.0        8977.0      21762.43   2056.08
# 187         1  2373082738   422.0       13601.0      16400.20   1843.27
# 212         1  1583584453   879.0       45729.5      45729.50   7464.54
# 262         1  8771395207    94.0        2700.0       2757.79    200.13
# ...       ...         ...     ...           ...           ...       ...
# 209337      1  9106790848   843.0        6309.0       6694.81   4182.61
# 209343      1  5072689231   766.0       12550.0      12792.85   1312.93
# 209401      1  7268589234   873.0        3350.0       3510.21   1504.48
# 209406      1  4165088659   268.0       10322.0      10322.00   2464.86
# 209580      1  1381982733  1365.0       18657.0      24825.00   6314.34
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
data[['payback30','payback90']].describe()
# Out:
#            payback30      payback90
# count  209593.000000  209593.000000
# mean        3.398826       4.321485
# std         8.813729      10.308108
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       1.666667
# 75%         3.750000       4.500000
# max       171.500000     171.500000

# %%
sb.boxplot(data['payback90'])
# Out:
# <AxesSubplot:xlabel='payback90'>

# %%
sb.scatterplot(data['label'],data['payback90'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='payback90'>

# %%
plt.figure(figsize=(6,4))
sb.barplot(data['label'],data['payback90'])
plt.xticks([0,1],['Defaulter','Non Defaulter'])
# Out:
# ([<matplotlib.axis.XTick at 0x1fa0c527ac0>,
# ...
#  [Text(0, 0, 'Defaulter'), Text(1, 0, 'Non Defaulter')])

# %% [markdown]
# #### HAndling Missing Values :
#     - Missing Values are nothing but the Unrealistic Values Present in the columns

# %%
(data.isnull()).sum(axis=0)
# Out:
# label                      0
# msisdn                     0
# aon                     2089
# daily_decr30               0
# daily_decr90               0
# rental30                   0
# rental90                   0
# last_rech_date_ma       2409
# last_rech_date_da       1407
# last_rech_amt_ma           0
# cnt_ma_rech30              0
# fr_ma_rech30            1047
# sumamnt_ma_rech30          0
# medianamnt_ma_rech30       0
# medianmarechprebal30       0
# cnt_ma_rech90              0
# fr_ma_rech90               0
# sumamnt_ma_rech90          0
# medianamnt_ma_rech90       0
# medianmarechprebal90       0
# cnt_da_rech30           1047
# fr_da_rech30            1047
# cnt_da_rech90              0
# fr_da_rech90               0
# cnt_loans30                0
# amnt_loans30               0
# maxamnt_loans30         1047
# medianamnt_loans30         0
# cnt_loans90             1047
# amnt_loans90               0
# maxamnt_loans90            0
# medianamnt_loans90         0
# ...

# %%
sb.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.shape
# Out:
# (209593, 35)

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (198690, 35)

# %% [markdown]
# ##### Observation
# - 5.2% loss of Data

# %% [markdown]
# ##### NOTE
#     WE drop msisdn,pdate  as it doesnot give much information about the target Class

# %%
data.drop(['msisdn','pdate'],inplace=True,axis=1)

# %%
plt.figure(figsize=(20,15))
sb.heatmap(data.corr(),annot=True,cmap='Set2')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Visualizing some Joint Plots to visualize relation between features

# %%
sb.jointplot(data['cnt_ma_rech90'],data['amnt_loans90'],hue=data['label'])

# %%
y = data['label']
corr_table = data.corr()

# %%
corr_table['label']
# Out:
# label                   1.000000
# aon                     0.080241
# daily_decr30            0.170006
# daily_decr90            0.167678
# rental30                0.058336
# rental90                0.075924
# last_rech_date_ma      -0.093455
# last_rech_date_da       0.019602
# last_rech_amt_ma        0.132112
# cnt_ma_rech30           0.239075
# fr_ma_rech30            0.144528
# sumamnt_ma_rech30       0.204524
# medianamnt_ma_rech30    0.141815
# medianmarechprebal30   -0.005533
# cnt_ma_rech90           0.238198
# fr_ma_rech90            0.083562
# sumamnt_ma_rech90       0.207312
# medianamnt_ma_rech90    0.121110
# medianmarechprebal90    0.039850
# cnt_da_rech30           0.003321
# fr_da_rech30           -0.004713
# cnt_da_rech90           0.004376
# fr_da_rech90           -0.004523
# cnt_loans30             0.198363
# amnt_loans30            0.199389
# maxamnt_loans30         0.075196
# medianamnt_loans30      0.044889
# cnt_loans90             0.202226
# ...

# %%
data.drop('label',inplace=True,axis=1)

# %%
data.skew()
# Out:
# aon                      0.945447
# daily_decr30             3.945770
# daily_decr90             4.272363
# rental30                 4.574615
# rental90                 4.470197
# last_rech_date_ma        3.455635
# last_rech_date_da        8.978059
# last_rech_amt_ma         3.679562
# cnt_ma_rech30            3.229742
# fr_ma_rech30             1.845936
# sumamnt_ma_rech30        6.407953
# medianamnt_ma_rech30     3.473798
# medianmarechprebal30    14.830320
# cnt_ma_rech90            3.423389
# fr_ma_rech90             2.295945
# sumamnt_ma_rech90        4.906399
# medianamnt_ma_rech90     3.747693
# medianmarechprebal90    45.320103
# cnt_da_rech30           31.087612
# fr_da_rech30            30.948596
# cnt_da_rech90           27.425028
# fr_da_rech90            29.110026
# cnt_loans30              2.700456
# amnt_loans30             2.954431
# maxamnt_loans30          1.430824
# medianamnt_loans30       4.562590
# cnt_loans90              2.991102
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198690 entries, 0 to 209592
# Data columns (total 32 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   aon                   198690 non-null  float64
#  1   daily_decr30          198690 non-null  float64
#  2   daily_decr90          198690 non-null  float64
#  3   rental30              198690 non-null  float64
#  4   rental90              198690 non-null  float64
#  5   last_rech_date_ma     198690 non-null  float64
#  6   last_rech_date_da     198690 non-null  float64
#  7   last_rech_amt_ma      198690 non-null  float64
#  8   cnt_ma_rech30         198690 non-null  int64
#  9   fr_ma_rech30          198690 non-null  float64
#  10  sumamnt_ma_rech30     198690 non-null  float64
#  11  medianamnt_ma_rech30  198690 non-null  float64
#  12  medianmarechprebal30  198690 non-null  float64
#  13  cnt_ma_rech90         198690 non-null  int64
# ...

# %% [markdown]
# # NOTE:
#
#     AS we have ouliers in our Data and these outliers are meaningfull, we use MinMax Scaler as we have well Defined Ranges and Standard scalar may be effected by OUtliers

# %%
from sklearn.preprocessing import PowerTransformer

# %%
data_1 = data

# %%
data_1.shape
# Out:
# (198690, 32)

# %%
power = PowerTransformer()

# %%
data_1 = power.fit_transform(data)

# %%
transformed_data = pd.DataFrame(data_1, columns=data.columns)

# %%
transformed_data.skew()
# Out:
# aon                      0.302847
# daily_decr30            -6.373196
# daily_decr90            -6.860033
# rental30                -1.168725
# rental90                -1.091199
# last_rech_date_ma        0.040986
# last_rech_date_da        6.001356
# last_rech_amt_ma        -0.065824
# cnt_ma_rech30           -0.000506
# fr_ma_rech30             0.133962
# sumamnt_ma_rech30       -0.295005
# medianamnt_ma_rech30    -0.193368
# medianmarechprebal30    -0.088835
# cnt_ma_rech90           -0.002946
# fr_ma_rech90             0.142453
# sumamnt_ma_rech90       -0.195148
# medianamnt_ma_rech90    -0.046879
# medianmarechprebal90     7.626552
# cnt_da_rech30            8.089205
# fr_da_rech30            19.584811
# cnt_da_rech90            6.000719
# fr_da_rech90            15.422196
# cnt_loans30              0.036996
# amnt_loans30             0.001998
# maxamnt_loans30          0.411022
# medianamnt_loans30       3.453808
# cnt_loans90              0.097674
# ...

# %%
transformed_data.shape
# Out:
# (198690, 32)

# %% [markdown]
# ##### **OBservation**:
#      - Highly Skewed Columns  medianamnt_loans90, medianamnt_loans30,  Medianprebal90, cnt_da_rech30,cnt_da_rech90,fr_da_rech30,fr_da_rech90, last_rech_date_da are vert less corelated to the Label, so we can drop these columns or USE PCA FOR DIMension Reduction of Data

# %%
data_5 = transformed_data
transformed_data
# Out:
#              aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      -0.731092      0.324242      0.291247 -0.582789 -0.570778
# 1       0.244211      1.112261      1.040824  0.336566  0.146497
# 2      -0.113849     -0.016215     -0.036799 -0.369102 -0.410961
# 3      -0.814785     -1.036762     -1.027789 -0.605060 -0.600228
# 4       0.677270     -0.690067     -0.688421 -0.312668 -0.366044
# ...          ...           ...           ...       ...       ...
# 198685 -0.404559     -0.688195     -0.686599 -0.315386 -0.368206
# 198686  0.898122     -0.956227     -0.948606 -0.143057 -0.231509
# 198687  0.792288      1.096585      1.029087  0.821285  1.019862
# 198688  1.920280      1.132439      1.064277 -0.517631 -0.391697
# 198689  1.698608      0.517853      0.479888 -0.494471 -0.474496
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0               -0.320918          -0.162244          0.085523      -0.277600
# ...

# %%
transformed_data.shape
# Out:
# (198690, 32)

# %%
transformed_data.shape
# Out:
# (198690, 32)

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# #### PCA: Feature engineering

# %%
pca = PCA()

# %%
pca.fit(transformed_data,y)
# Out:
# PCA()

# %%
plt.figure(figsize=(8,5))
plt.bar(range(0,32),np.cumsum(pca.explained_variance_ratio_))
plt.title('Component Analysis Vs % Data Information')
plt.xlabel('No of Components')
plt.ylabel('% of Information Gain ')
# Out:
# Text(0, 0.5, '% of Information Gain ')

# %% [markdown]
# ##### Note:
#     - From the Graph, we can choose any component between20-25, as they give more than 95% information on Target Class.
#     - I choose 24 Components

# %%
pca = PCA(n_components=24)

# %%
features = pca.fit_transform(transformed_data,y)

# %%
pca_data = pd.DataFrame(features,columns=range(1,25))

# %% [markdown]
# ### Class Imbalanced problem: Using SMOTHE
#     - SMOTHE is used to remove class imbalance and perform oversampling of the minority class .

# %%
from imblearn.over_sampling import SMOTE

# %%
sm =SMOTE()
x_sample,y_sample =sm.fit_resample(pca_data,y)

# %%
y_sample.value_counts()
# Out:
# 1    173668
# 0    173668
# Name: label, dtype: int64

# %%
x_sample.shape
# Out:
# (347336, 24)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve,classification_report,confusion_matrix

# %% [markdown]
# #### MODEL TRAINING:
# #### Choosing Random State

# %%
maxA = 0
maxrs = 0
log = LogisticRegression()
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x_sample,y_sample,random_state=i,test_size=.30)
    log.fit(x_train,y_train)
    pred= log.predict(x_test)
    aacc = accuracy_score(y_test,pred)
    if(aacc>maxA):
        maxA = aacc
        maxrs = i
    print('Accuracy:',aacc,' Random State : ',i)
print(' Best Accuracy ',maxA,' with Best random State of ', maxrs)
# Out:
# Accuracy: 0.7703572902371378  Random State :  1
# Accuracy: 0.7717488315851095  Random State :  2
# Accuracy: 0.7715952821949885  Random State :  3
# Accuracy: 0.769848657882362  Random State :  4
# Accuracy: 0.7675742075411944  Random State :  5
# Accuracy: 0.7677565474419631  Random State :  6
# Accuracy: 0.7717104442375793  Random State :  7
# Accuracy: 0.7679964683640272  Random State :  8
# Accuracy: 0.7702421281945471  Random State :  9
# Accuracy: 0.7697622863504189  Random State :  10
# Accuracy: 0.7702229345207819  Random State :  11
# Accuracy: 0.7686682469458067  Random State :  12
# Accuracy: 0.7706931795280275  Random State :  13
# Accuracy: 0.7687546184777497  Random State :  14
# Accuracy: 0.7685242943925682  Random State :  15
# Accuracy: 0.7694839780808246  Random State :  16
# Accuracy: 0.7701941440101343  Random State :  17
# Accuracy: 0.7701845471732517  Random State :  18
# Accuracy: 0.7712210055565686  Random State :  19
# ...

# %%
print(' Best Accuracy ',maxA,' with Best random State of ', maxrs)
# Out:
#  Best Accuracy  0.7725645627201274  with Best random State of  192

# %%
 x_train,x_test,y_train,y_test = train_test_split(x_sample,y_sample,random_state=maxrs,test_size=.25)

# %%
cv_scores = []
accuracy_scores = []
auc_scores = []
time_taken = []

# %% [markdown]
# ## 5. Modeling DIFFERENT Models: Logistic, Decision Tree, Random Forest, AdaBoost, GraidentBoost
#     - SVM and KNN not included due to time Constraints.
#
# #### 5.1 LOGISTIC REGRESSION

# %%
import timeit

# %%
starttime = timeit.default_timer()
logModel = LogisticRegression()
logModel.fit(x_train,y_train)
pred_lr = logModel.predict(x_test)

score = accuracy_score(y_test,pred_lr)
cv_score = np.mean(cross_val_score(logModel,x_sample,y_sample,cv=5))
pred_lr_proba = logModel.predict_proba(x_test)[:,1]
roc_score = roc_auc_score(y_test,pred_lr_proba)
print('Accuracy Score of Logistic Model: ',score)
print('Training Score of Logistic Model: ', cv_score)
print('ROC_AUC Score of Logistic Model: ', roc_score)
fpr,tpr,threshold = roc_curve(y_test,pred_lr_proba)
accuracy_scores.append(score)
cv_scores.append(cv_score)
auc_scores.append(roc_score)
plt.figure(figsize=(10,5))
plt.plot(fpr,tpr)
plt.title('Roc Curve  of Logistic Model')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True positive Rate ( Sensitivity )')
print("The time difference is :", timeit.default_timer() - starttime)
time_t = timeit.default_timer() - starttime
time_taken.append(time_t)
# Out:
# Accuracy Score of Logistic Model:  0.7725314968791026
# Training Score of Logistic Model:  0.7697906449437631
# ROC_AUC Score of Logistic Model:  0.8468762003764303
# The time difference is : 7.081844999999987

# %%
print('-------------Logistic MODEL---------------')
import scikitplot as skplt
print(classification_report(y_test,pred_lr))



skplt.metrics.plot_confusion_matrix(  y_test,  pred_lr,figsize=(7,5))
# Out:
# -------------Logistic MODEL---------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.78     43464
#            1       0.78      0.75      0.77     43370
#
#     accuracy                           0.77     86834
#    macro avg       0.77      0.77      0.77     86834
# weighted avg       0.77      0.77      0.77     86834
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# ### LINEARSVC MODEL

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC(random_state=0, tol=1e-5)

clf.fit(x_train, y_train.ravel())
# Out:
# LinearSVC(random_state=0, tol=1e-05)

# %%
 pred_lsvc = clf.predict(x_test)
accuracy_score(y_test,pred_lsvc)
# Out:
# 0.7719672017873184

# %%
print('--------------SVC Model--------------------')
print(classification_report(y_test,pred_lsvc))

skplt.metrics.plot_confusion_matrix(  y_test,  pred_lsvc,figsize=(7,5))
# Out:
# --------------SVC Model--------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.78     43464
#            1       0.78      0.76      0.77     43370
#
#     accuracy                           0.77     86834
#    macro avg       0.77      0.77      0.77     86834
# weighted avg       0.77      0.77      0.77     86834
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# #### 5.2 Decision Tree Classifer

# %%
starttime = timeit.default_timer()
decisionTree = DecisionTreeClassifier()
decisionTree.fit(x_train,y_train)
pred_dtc = decisionTree.predict(x_test)

score = accuracy_score(y_test,pred_dtc)
cv_score = np.mean(cross_val_score(decisionTree,x_sample,y_sample,cv=5))
pred_dtc_proba = decisionTree.predict_proba(x_test)[:,1]
roc_score = roc_auc_score(y_test,pred_dtc_proba)
print('--------------DEcision TRee Model--------------------')
print('Accuracy Score of DecisionTreeClassifer Model: ',score)
print('Training Score of DecisionTreeClassifer Model: ', cv_score)
print('ROC_AUC Score of DecisionTreeClassifer Model: ', roc_score)
fpr,tpr,threshold = roc_curve(y_test,pred_dtc_proba)
accuracy_scores.append(score)
cv_scores.append(cv_score)
auc_scores.append(roc_score)


plt.figure(figsize=(10,5))
plt.plot(fpr,tpr)
plt.title('Roc Curve  of DecisionTreeClassifer Model')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True positive Rate ( Sensitivity )')
print("The time difference is :", timeit.default_timer() - starttime)
time_t = timeit.default_timer() - starttime
time_taken.append(time_t)
# Out:
# --------------DEcision TRee Model--------------------
# Accuracy Score of DecisionTreeClassifer Model:  0.856392657254071
# Training Score of DecisionTreeClassifer Model:  0.860734278467487
# ROC_AUC Score of DecisionTreeClassifer Model:  0.8562696983217828
# The time difference is : 81.54619839999998

# %%
print('--------------DEcision TRee Model--------------------')
print(classification_report(y_test,pred_dtc))

skplt.metrics.plot_confusion_matrix(  y_test,  pred_dtc,figsize=(7,5))
# Out:
# --------------DEcision TRee Model--------------------
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86     43464
#            1       0.87      0.83      0.85     43370
#
#     accuracy                           0.86     86834
#    macro avg       0.86      0.86      0.86     86834
# weighted avg       0.86      0.86      0.86     86834
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# ### 5.3 RandomForestClassifer

# %%
starttime = timeit.default_timer()
RandomForest = RandomForestClassifier()
RandomForest.fit(x_train,y_train)
pred_rfc = RandomForest.predict(x_test)

score = accuracy_score(y_test,pred_rfc)
cv_score = np.mean(cross_val_score(RandomForest,x_sample,y_sample,cv=5))
pred_rf_proba = RandomForest.predict_proba(x_test)[:,1]
roc_score = roc_auc_score(y_test,pred_rf_proba)
print('Accuracy Score of Random Forest Model: ',score)
print('Training Score of Random Forest Model: ', cv_score)
print('ROC_AUC Score of Random Forest Model: ', roc_score)
fpr,tpr,threshold = roc_curve(y_test,pred_rf_proba)
accuracy_scores.append(score)
cv_scores.append(cv_score)
auc_scores.append(roc_score)


plt.figure(figsize=(10,5))
plt.plot(fpr,tpr)
plt.title('Roc Curve  of Random Forest Model')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True positive Rate ( Sensitivity )')
print("The time difference is :", timeit.default_timer() - starttime)
time_t = timeit.default_timer() - starttime
time_taken.append(time_t)
# Out:
# Accuracy Score of Random Forest Model:  0.9260427942971647
# Training Score of Random Forest Model:  0.9292155182966344
# ROC_AUC Score of Random Forest Model:  0.9763728958943587
# The time difference is : 994.7050144

# %%
print('--------------RandomForest  Model--------------------')
print(classification_report(y_test,pred_rfc))
skplt.metrics.plot_confusion_matrix(  y_test,  pred_rfc,figsize=(7,5))
# Out:
# --------------RandomForest  Model--------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93     43464
#            1       0.94      0.91      0.93     43370
#
#     accuracy                           0.93     86834
#    macro avg       0.93      0.93      0.93     86834
# weighted avg       0.93      0.93      0.93     86834
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# ### 5.4 AdaBoostClassifer

# %%
starttime = timeit.default_timer()
AdaBoost = AdaBoostClassifier()
AdaBoost.fit(x_train,y_train)
pred_abc = AdaBoost.predict(x_test)

score = accuracy_score(y_test,pred_abc)
cv_score = np.mean(cross_val_score(AdaBoost,x_sample,y_sample,cv=5))
pred_abc_proba = AdaBoost.predict_proba(x_test)[:,1]
roc_score = roc_auc_score(y_test,pred_abc_proba)
print('Accuracy Score of AdaBoost Classifer Model: ',score)
print('Training Score of AdaBoost Classifer Model: ', cv_score)
print('ROC_AUC Score of AdaBoost Classifer Model: ', roc_score)
fpr,tpr,threshold = roc_curve(y_test,pred_abc_proba)
accuracy_scores.append(score)
cv_scores.append(cv_score)
auc_scores.append(roc_score)


plt.figure(figsize=(10,5))
plt.plot(fpr,tpr)
plt.title('Roc Curve  of AdaBoost Classifer Model')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True positive Rate ( Sensitivity )')
print("The time difference is :", timeit.default_timer() - starttime)
time_t = timeit.default_timer() - starttime
time_taken.append(time_t)
# Out:
# Accuracy Score of AdaBoost Classifer Model:  0.7775640877997098
# Training Score of AdaBoost Classifer Model:  0.7749153672503339
# ROC_AUC Score of AdaBoost Classifer Model:  0.8587393494210671
# The time difference is : 373.55781479999996

# %%
print('--------------ADABoostClassifer  Model--------------------')
print(classification_report(y_test,pred_abc))
skplt.metrics.plot_confusion_matrix(  y_test,  pred_abc,figsize=(7,5))
# Out:
# --------------ADABoostClassifer  Model--------------------
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78     43464
#            1       0.78      0.76      0.77     43370
#
#     accuracy                           0.78     86834
#    macro avg       0.78      0.78      0.78     86834
# weighted avg       0.78      0.78      0.78     86834
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
error = []
for i in range(0,4):
    error.append(np.abs(accuracy_scores[i] - cv_scores[i]))

# %%
table_details = {
                'Training Score (CV)' : cv_scores,
                'RocAucSocre': auc_scores,
    'AccuracyScores': accuracy_scores,
    'Error Metrics (Evaluation Score - Training)': error,
    'Time Taken for Execution': time_taken
}

# %%
table = pd.DataFrame(table_details,index=['Logistic','DTC','RF','ADB'])

# %%
table
# Out:
#           Training Score (CV)  RocAucSocre  AccuracyScores  \
# Logistic             0.769791     0.846876        0.772531
# DTC                  0.860734     0.856270        0.856393
# RF                   0.929216     0.976373        0.926043
# ADB                  0.774915     0.858739        0.777564
#
#           Error Metrics (Evaluation Score - Training)  \
# Logistic                                     0.002741
# DTC                                          0.004342
# RF                                           0.003173
# ADB                                          0.002649
#
#           Time Taken for Execution
# Logistic                  7.081978
# DTC                      81.546311
# RF                      994.705330
# ADB                     373.557960

# %% [markdown]
# #### **Observation**,
#     - Accuracy Score is highest for Random Forest, But Execution Time IS too High making the model slow.
#     - Decision Tree or Boosting Technique  have equally least error metrics .
#     - For a Ml Model, Accuracy is the most important characteristic w.r.t to Model Time Performance.
#     - We choose least error metrics model with higher performance ,as all models have equal least error metric, we choose
#     highest Accuracy Model i.e Random Forest

# %% [markdown]
# #### Evaluate Choosen Model: Random Forest

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
RandomForest = RandomForestClassifier()

# %%
RandomForest = RandomForestClassifier(n_estimators=150)
RandomForest.fit(x_train,y_train)
pred_rfc = RandomForest.predict(x_test)

score = accuracy_score(y_test,pred_rfc)

pred_rf_proba = RandomForest.predict_proba(x_test)[:,1]

roc_score = roc_auc_score(y_test,pred_rf_proba)
cv_score = np.mean(cross_val_score(RandomForest,x_sample,y_sample,cv=5))

print('Accuracy Score of Random Forest Model: ',score)
print('Training Score of Random Forest Model: ', cv_score)
print('ROC_AUC Score of Random Forest Model: ', roc_score)
# Out:
# Accuracy Score of Random Forest Model:  0.9268028652371191
# Training Score of Random Forest Model:  0.9303498668337999
# ROC_AUC Score of Random Forest Model:  0.976776234841597

# %%
fpr,tpr,threshold = roc_curve(y_test,pred_rf_proba)


plt.figure(figsize=(10,5))
plt.plot(fpr,tpr)
plt.title('Roc Curve  of Random Forest Model')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True positive Rate ( Sensitivity )')
# Out:
# Text(0, 0.5, 'True positive Rate ( Sensitivity )')

# %%
print('Classification Report OF Random Forest Model',classification_report(y_test,pred_rfc))
print('Confusion MatrixOF Random Forest Model')

print(confusion_matrix(y_test,pred_rfc))
# Out:
# Classification Report OF Random Forest Model               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93     43464
#            1       0.94      0.91      0.93     43370
#
#     accuracy                           0.93     86834
#    macro avg       0.93      0.93      0.93     86834
# weighted avg       0.93      0.93      0.93     86834
#
# Confusion MatrixOF Random Forest Model
# [[40817  2647]
#  [ 3709 39661]]

# %%
params = {
        'n_estimators' :  [100,150,200,300],
        'max_depth' : range(20,30)
    
}
grid = GridSearchCV(RandomForest,params,cv=5,scoring='accuracy')

# %%
grid.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-152-807fe847b3e2> in <module>
# ----> 1 grid.fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
# ...

# %%
import joblib

# %%
joblib.dump(RandomForest,'creditDefaulterRandomForest.pk')
# Out:
# ['creditDefaulterRandomForest.pk']

# %%
model = joblib.load('creditDefaulterRandomForest.pk')

# %%
:
